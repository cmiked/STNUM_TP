# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('concrete_compressive_strength.csv', sep=';', dtype=float, decimal=',' )
units = ['Kg par m^3', 'Kg par m^3', 'Kg par m^3', 'Kg par m^3', 'Kg par m^3','Kg par m^3', 'Kg par m^3', 'jours', 'MPa' ]
titles = ['Contenu en ciment', 'laitier de haut fourneau', 'cendres volatiles', 'eau', 'superplastifiant', 'granulat grossier', 'granulat fin', 'âge', 'résistence à la compr.']
df
# Out:
#       cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       coarse_aggregate  fine_aggregate    age  compressive_strength
# 0               1040.0           676.0   28.0             79.986111
# ...

# %%
df.dtypes
# Out:
# cement                  float64
# blast_furnace_slag      float64
# fly_ash                 float64
# water                   float64
# superplasticizer        float64
# coarse_aggregate        float64
# fine_aggregate          float64
# age                     float64
# compressive_strength    float64
# dtype: object

# %%
#pd.plotting.scatter_matrix(df, figsize=(13, 10))
#plt.show()

# %%
histAx = df.hist(figsize=(13, 10))

for i, ax in enumerate(histAx.flatten()):
    ax.set_xlabel(units[i])
    ax.set_ylabel('Frequency')
    ax.set_title(titles[i])
plt.show()

# %%
summary = df.describe()
summary = summary.transpose()
summary.drop(axis=1, labels='count')
# Out:
#                             mean         std         min         25%  \
# cement                281.165631  104.507142  102.000000  192.375000
# blast_furnace_slag     73.895485   86.279104    0.000000    0.000000
# fly_ash                54.187136   63.996469    0.000000    0.000000
# water                 181.566359   21.355567  121.750000  164.900000
# superplasticizer        6.203112    5.973492    0.000000    0.000000
# coarse_aggregate      972.918592   77.753818  801.000000  932.000000
# fine_aggregate        773.578883   80.175427  594.000000  730.950000
# age                    45.662136   63.169912    1.000000    7.000000
# compressive_strength   35.817836   16.705679    2.331808   23.707115
#
#                              50%          75%          max
# cement                272.900000   350.000000   540.000000
# blast_furnace_slag     22.000000   142.950000   359.400000
# fly_ash                 0.000000   118.270000   200.100000
# ...
